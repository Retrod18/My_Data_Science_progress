# %%
import kagglehub
print('done')
# Out:
# done

# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\admin\anaconda3\lib\site-packages (0.3.12)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\admin\anaconda3\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->kagglehub) (2025.6.15)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("manishkr1754/cardekho-used-car-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Admin\.cache\kagglehub\datasets\manishkr1754\cardekho-used-car-data\versions\2

# %%
import os
all_files=os.listdir(path)

# %%
file_path=path+'\\'+all_files[0]
file_path
# Out:
# 'C:\\Users\\Admin\\.cache\\kagglehub\\datasets\\manishkr1754\\cardekho-used-car-data\\versions\\2\\cardekho_dataset.csv'

# %%
import pandas as pd
df=pd.read_csv(file_path)
print('done')
# Out:
# done

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
r,c=df.shape
print(f'''dataset contains
rows={r}
columns={c}''')
# Out:
# dataset contains
# rows=15411
# columns=14

# %%
#list ofcolumns
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
# 'Unnamed: 0': Wrong Col
df.drop('Unnamed: 0',axis = 1,inplace=True)

# %%
df.sample(3)
# Out:
#                  car_name    brand        model  vehicle_age  km_driven  \
# 5497          Hyundai i20  Hyundai          i20            7      37000
# 12525               BMW 3      BMW            3            8      60000
# 12561  Maruti Swift Dzire   Maruti  Swift Dzire            4      50000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 5497       Dealer    Petrol            Manual    18.60    1197      81.83
# 12525      Dealer    Diesel         Automatic    16.07    1995     181.00
# 12561  Individual    Diesel         Automatic    28.40    1248      74.02
#
#        seats  selling_price
# 5497       5         495000
# 12525      4        1300000
# 12561      5         850000

# %%
#missing value
df.isna().sum() #zero represents no null value found
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
# graph/viusals : heatmap
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#missing valus:
# replace/fill/remove/ignore
#stats:by_default:numerical():ignore:object/category
df.describe().round(2)
# Out:
#        vehicle_age   km_driven   mileage    engine  max_power     seats  \
# count     15411.00    15411.00  15411.00  15411.00   15411.00  15411.00
# mean          6.04    55616.48     19.70   1486.06     100.59      5.33
# std           3.01    51618.55      4.17    521.11      42.97      0.81
# min           0.00      100.00      4.00    793.00      38.40      0.00
# 25%           4.00    30000.00     17.00   1197.00      74.00      5.00
# 50%           6.00    50000.00     19.67   1248.00      88.50      5.00
# 75%           8.00    70000.00     22.70   1582.00     117.30      5.00
# max          29.00  3800000.00     33.54   6592.00     626.00      9.00
#
#        selling_price
# count       15411.00
# mean       774971.12
# std        894128.36
# min         40000.00
# 25%        385000.00
# 50%        556000.00
# 75%        825000.00
# max      39500000.00

# %%
df.describe(include='object')
# Out:
#            car_name   brand  model seller_type fuel_type transmission_type
# count         15411   15411  15411       15411     15411             15411
# unique          121      32    120           3         5                 2
# top     Hyundai i20  Maruti    i20      Dealer    Petrol            Manual
# freq            906    4992    906        9539      7643             12225

# %%
# Findings:
# Car dekho website has most demanded model i20 freq: 906
# Analysis
# Univariate, Bivariate and Multivariate data and its analysis
# Univariate,: Single col
# Bivariate : double col
# Multivariate: more than 2 col

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
# Univariate: Single Col Analysis
cat_col=list(df.describe(include=['object']).columns)
num_col=list(df.describe().columns)

# %%
print(cat_col)
# Out:
# ['car_name', 'brand', 'model', 'seller_type', 'fuel_type', 'transmission_type']

# %%
# unique, # nunique, value_count
# series: single col(series)

# %%
df['car_name']
# Out:
# 0            Maruti Alto
# 1          Hyundai Grand
# 2            Hyundai i20
# 3            Maruti Alto
# 4          Ford Ecosport
#               ...
# 15406        Hyundai i10
# 15407      Maruti Ertiga
# 15408        Skoda Rapid
# 15409    Mahindra XUV500
# 15410         Honda City
# Name: car_name, Length: 15411, dtype: object

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# value_counts()
# Top 10 Car By Name
df['car_name'].value_counts().head(10)
# Out:
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Maruti Wagon R        717
# Hyundai Grand         580
# Toyota Innova         545
# Hyundai Verna         492
# Hyundai i10           410
# Name: count, dtype: int64

# %%
df['car_name'].value_counts().tail(10)
# Out:
# car_name
# ISUZU MUX                2
# Hyundai Aura             1
# Maserati Ghibli          1
# Ferrari GTC4Lusso        1
# Tata Altroz              1
# Mercedes-AMG C           1
# Rolls-Royce Ghost        1
# Maserati Quattroporte    1
# Isuzu MUX                1
# Force Gurkha             1
# Name: count, dtype: int64

# %%
for i in cat_col:
    print(f'\n\n top 10 analysisby{i}\n')
    display(df[i].value_counts().head())
# Out:
#  top 10 analysisbycar_name
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Name: count, dtype: int64
#  top 10 analysisbybrand
# brand
# Maruti      4992
# Hyundai     2982
# Honda       1485
# Mahindra    1011
# Toyota       793
# Name: count, dtype: int64
#  top 10 analysisbymodel
# model
# i20            906
# Swift Dzire    890
# Swift          781
# Alto           778
# City           757
# Name: count, dtype: int64
#  top 10 analysisbyseller_type
# seller_type
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: count, dtype: int64
#  top 10 analysisbyfuel_type
# fuel_type
# Petrol      7643
# Diesel      7419
# CNG          301
# LPG           44
# Electric       4
# Name: count, dtype: int64
#  top 10 analysisbytransmission_type
# transmission_type
# Manual       12225
# Automatic     3186
# Name: count, dtype: int64

# %%
for i in cat_col:
  print(f'\n\nTop 10 Analysis by {i}\n')
  display(df[i].value_counts().head(10))
# Out:
# Top 10 Analysis by car_name
# car_name
# Hyundai i20           906
# Maruti Swift Dzire    890
# Maruti Swift          781
# Maruti Alto           778
# Honda City            757
# Maruti Wagon R        717
# Hyundai Grand         580
# Toyota Innova         545
# Hyundai Verna         492
# Hyundai i10           410
# Name: count, dtype: int64
# Top 10 Analysis by brand
# brand
# Maruti        4992
# Hyundai       2982
# Honda         1485
# Mahindra      1011
# Toyota         793
# Ford           790
# Volkswagen     620
# Renault        536
# BMW            439
# Tata           430
# Name: count, dtype: int64
# Top 10 Analysis by model
# model
# i20            906
# Swift Dzire    890
# Swift          781
# Alto           778
# City           757
# Wagon R        717
# Grand          580
# Innova         545
# Verna          492
# i10            410
# Name: count, dtype: int64
# Top 10 Analysis by seller_type
# seller_type
# Dealer              9539
# Individual          5699
# Trustmark Dealer     173
# Name: count, dtype: int64
# Top 10 Analysis by fuel_type
# fuel_type
# Petrol      7643
# Diesel      7419
# CNG          301
# LPG           44
# Electric       4
# Name: count, dtype: int64
# Top 10 Analysis by transmission_type
# transmission_type
# Manual       12225
# Automatic     3186
# Name: count, dtype: int64

# %%
top_10_series = df['car_name'].value_counts().head(10)
(top_10_series/top_10_series.sum())*100
# Out:
# car_name
# Hyundai i20           13.214702
# Maruti Swift Dzire    12.981330
# Maruti Swift          11.391482
# Maruti Alto           11.347725
# Honda City            11.041424
# Maruti Wagon R        10.457993
# Hyundai Grand          8.459743
# Toyota Innova          7.949242
# Hyundai Verna          7.176196
# Hyundai i10            5.980163
# Name: count, dtype: float64

# %%
# Top 10 Analysis For Categorical Columns

for i in cat_col:
  print(f'\n\nTop 10 Analysis by {i}\n')
  top_10 = df[i].value_counts().head(10)
  (top_10/top_10.sum())*10
# Out:
# Top 10 Analysis by car_name
#
#
#
# Top 10 Analysis by brand
#
#
#
# Top 10 Analysis by model
#
#
#
# Top 10 Analysis by seller_type
#
#
#
# Top 10 Analysis by fuel_type
#
#
#
# Top 10 Analysis by transmission_type

# %%
# top_10_series = df['car_name'].value_counts().head(10)
# (top_10_series/r)*100

# %%
# Top 10 Analysis For Categorical Columns in %

for i in cat_col:
  print(f'\n\nTop 10 Analysis by {i}\n')
  top_10 = df[i].value_counts().head(10)

  ans = (top_10/top_10.sum())*100

  display(ans.round(2))
# Out:
# Top 10 Analysis by car_name
# car_name
# Hyundai i20           13.21
# Maruti Swift Dzire    12.98
# Maruti Swift          11.39
# Maruti Alto           11.35
# Honda City            11.04
# Maruti Wagon R        10.46
# Hyundai Grand          8.46
# Toyota Innova          7.95
# Hyundai Verna          7.18
# Hyundai i10            5.98
# Name: count, dtype: float64
# Top 10 Analysis by brand
# brand
# Maruti        35.46
# Hyundai       21.18
# Honda         10.55
# Mahindra       7.18
# Toyota         5.63
# Ford           5.61
# Volkswagen     4.40
# Renault        3.81
# BMW            3.12
# Tata           3.05
# Name: count, dtype: float64
# Top 10 Analysis by model
# model
# i20            13.21
# Swift Dzire    12.98
# Swift          11.39
# Alto           11.35
# City           11.04
# Wagon R        10.46
# Grand           8.46
# Innova          7.95
# Verna           7.18
# i10             5.98
# Name: count, dtype: float64
# Top 10 Analysis by seller_type
# seller_type
# Dealer              61.90
# Individual          36.98
# Trustmark Dealer     1.12
# Name: count, dtype: float64
# Top 10 Analysis by fuel_type
# fuel_type
# Petrol      49.59
# Diesel      48.14
# CNG          1.95
# LPG          0.29
# Electric     0.03
# Name: count, dtype: float64
# Top 10 Analysis by transmission_type
# transmission_type
# Manual       79.33
# Automatic    20.67
# Name: count, dtype: float64

# %%
# bottom 10 Analysis For Categorical Columns in %

for i in cat_col:
  print(f'\n\nbottom 10 Analysis by {i}\n')
  bottom_10 = df[i].value_counts().tail(10)

  ans = (bottom_10/bottom_10.sum())*100

  display(ans.round(2))
# Out:
# bottom 10 Analysis by car_name
# car_name
# ISUZU MUX                18.18
# Hyundai Aura              9.09
# Maserati Ghibli           9.09
# Ferrari GTC4Lusso         9.09
# Tata Altroz               9.09
# Mercedes-AMG C            9.09
# Rolls-Royce Ghost         9.09
# Maserati Quattroporte     9.09
# Isuzu MUX                 9.09
# Force Gurkha              9.09
# Name: count, dtype: float64
# bottom 10 Analysis by brand
# brand
# Nissan          27.5
# Lexus           25.0
# Isuzu           20.0
# Bentley          7.5
# Maserati         5.0
# ISUZU            5.0
# Ferrari          2.5
# Mercedes-AMG     2.5
# Rolls-Royce      2.5
# Force            2.5
# Name: count, dtype: float64
# bottom 10 Analysis by model
# model
# Dzire LXI       16.67
# Macan           16.67
# Ghibli           8.33
# Aura             8.33
# GTC4Lusso        8.33
# Altroz           8.33
# C                8.33
# Ghost            8.33
# Quattroporte     8.33
# Gurkha           8.33
# Name: count, dtype: float64
# bottom 10 Analysis by seller_type
# seller_type
# Dealer              61.90
# Individual          36.98
# Trustmark Dealer     1.12
# Name: count, dtype: float64
# bottom 10 Analysis by fuel_type
# fuel_type
# Petrol      49.59
# Diesel      48.14
# CNG          1.95
# LPG          0.29
# Electric     0.03
# Name: count, dtype: float64
# bottom 10 Analysis by transmission_type
# transmission_type
# Manual       79.33
# Automatic    20.67
# Name: count, dtype: float64

# %%
df['car_name'].value_counts().head(10).plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
x = df['car_name'].value_counts().head(10).index
y = df['car_name'].value_counts().head(10).values

plt.figure(figsize = (8,4))
plt.title('Top 10 Car Name By Inventory',fontsize = 20,color = 'Green')
# ax = plt.bar(x,y, color = 'red')
ax = plt.bar(x,y, color = sns.color_palette('hot',10))
plt.bar_label(ax)
plt.xticks(rotation = 45)
plt.show()

# %%
import matplotlib.pyplot as plt

def graph_plot(col_name):

  x = df[col_name].value_counts().head(10).index
  y = df[col_name].value_counts().head(10).values

  plt.figure(figsize = (8,5))
  plt.title(f'Top 10 {col_name} By Inventory',fontsize = 20,color = 'Brown')
  # ax = plt.bar(x,y, color = 'red')

  ax = plt.bar(x,y, color = sns.color_palette('rainbow',10))  # cool, hot, rainbow, # magma
  plt.bar_label(ax)
  plt.xticks(rotation = 45)
  plt.show()

# %%
for i in cat_col:
    graph_plot(i)

# %%
df['selling_price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
plt.hist(df['selling_price'],bins = np.linspace(df['selling_price'].min(),df['selling_price'].max(),100))
plt.show()

# %%
import numpy as np

def plot_hist(col_name,bin_size = 100):
  plt.title(f'{col_name} Distribution Analysis'.upper(),fontsize = 20,color = 'Red')
  plt.hist(df[col_name],color = 'red',bins = np.linspace(df[col_name].min(),df[col_name].max(),bin_size))

  plt.show()

# %%
plot_hist('vehicle_age')
plot_hist('mileage')

# %%
plot_hist(i)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plot_hist(i)
#
# Cell In[40], line 5, in plot_hist(col_name, bin_size)
#       3 def plot_hist(col_name,bin_size = 100):
#       4   plt.title(f'{col_name} Distribution Analysis'.upper(),fontsize = 20,color = 'Red')
# ----> 5   plt.hist(df[col_name],color = 'red',bins = np.linspace(df[col_name].min(),df[col_name].max(),bin_size))
#       7   plt.show()
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\function_base.py:137, in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     135 conv = _array_converter(start, stop)
#     136 start, stop = conv.as_arrays()
# --> 137 dt = conv.result_type(ensure_inexact=True)
#     139 if dtype is None:
#     140     dtype = dt
#
# DTypePromotionError: The DType <class 'numpy.dtypes._PyFloatDType'> could not be promoted by <class 'numpy.dtypes.StrDType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes.StrDType'>, <class 'numpy.dtypes._PyFloatDType'>)

# %%
for i in num_col:
  plot_hist(i)

# %%
#how to filter
df['mileage'].min()

# %%
df[df['selling_price']>df['selling_price'].min()]

# %%
sec_min_price=df['selling_price'].sort_values().values[-2]
df[df['selling_price']==sec_min_price]

# %%
# Top 10 cars by sp

top_10_sp_df = df.sort_values(by = 'vehicle_age',ascending = False).head(10)

# %%
top_10_sp_df[['car_name','vehicle_age','fuel_type','selling_price']]

# %%
df.sort_values(by = 'vehicle_age',ascending = False).head(10)[['car_name','vehicle_age','fuel_type','selling_price']]

# %%
# unique
df['brand'].unique()

# %%
df['brand'].nunique()

# %%
# group by

df.groupby('brand')['selling_price'].mean().round(2).sort_values(ascending = False)

# %%
df.groupby('seller_type')['selling_price'].agg(['min','max','mean']).round()
