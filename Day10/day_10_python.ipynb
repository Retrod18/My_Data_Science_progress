# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:
  import numpy as np
  import matplotlib.pyplot as plt
  import time
  a = np.random.randint(0,255,(5,6,3))
  plt.imshow(a)
  plt.show()
  time.sleep(0.3)
  display(clear = false)

# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[ 36,  52, 229],
#         [187, 149,  45],
#         [ 34, 212, 134],
#         [193, 209,  36]],
#
#        [[181,  50, 122],
#         [ 95, 192, 186],
#         [ 39,   1,  40],
#         [160,   0,  95]],
#
#        [[  3,  58, 205],
#         [217,  59,  70],
#         [ 88,  56,  50],
#         [ 83, 120,  92]],
#
#        [[152, 167, 207],
#         [ 78,   4, 202],
#         [151, 229, 220],
#         [ 81, 170, 225]]], dtype=int32)

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[1])

# %%
plt.imshow(a)

# %%
np.split(a,2,axis = 1)
# Out:
# [array([[[ 36,  52, 229],
#          [187, 149,  45]],
#
#         [[181,  50, 122],
#          [ 95, 192, 186]],
#
#         [[  3,  58, 205],
#          [217,  59,  70]],
#
#         [[152, 167, 207],
#          [ 78,   4, 202]]], dtype=int32),
#  array([[[ 34, 212, 134],
#          [193, 209,  36]],
#
#         [[ 39,   1,  40],
#          [160,   0,  95]],
#
#         [[ 88,  56,  50],
#          [ 83, 120,  92]],
#
#         [[151, 229, 220],
#          [ 81, 170, 225]]], dtype=int32)]

# %%
a
# Out:
# array([[[ 36,  52, 229],
#         [187, 149,  45],
#         [ 34, 212, 134],
#         [193, 209,  36]],
#
#        [[181,  50, 122],
#         [ 95, 192, 186],
#         [ 39,   1,  40],
#         [160,   0,  95]],
#
#        [[  3,  58, 205],
#         [217,  59,  70],
#         [ 88,  56,  50],
#         [ 83, 120,  92]],
#
#        [[152, 167, 207],
#         [ 78,   4, 202],
#         [151, 229, 220],
#         [ 81, 170, 225]]], dtype=int32)

# %%
arr_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 arr_1
#
# NameError: name 'arr_1' is not defined

# %%
arr_1 = np.split(a,2,axis = 1)

# %%
len(arr_1)
# Out:
# 2

# %%
a.shape
# Out:
# (4, 4, 3)

# %%
np.split(a,3, axis = 2)
# Out:
# [array([[[ 36],
#          [187],
#          [ 34],
#          [193]],
#
#         [[181],
#          [ 95],
#          [ 39],
#          [160]],
#
#         [[  3],
#          [217],
#          [ 88],
#          [ 83]],
#
#         [[152],
#          [ 78],
#          [151],
#          [ 81]]], dtype=int32),
#  array([[[ 52],
#          [149],
#          [212],
#          [209]],
#
#         [[ 50],
#          [192],
#          [  1],
#          [  0]],
#
#         [[ 58],
#          [ 59],
#          [ 56],
#          [120]],
#
#         [[167],
#          [  4],
#          [229],
#          [170]]], dtype=int32),
#  array([[[229],
#          [ 45],
#          [134],
#          [ 36]],
#
#         [[122],
#          [186],
#          [ 40],
#          [ 95]],
#
#         [[205],
#          [ 70],
#          [ 50],
#          [ 92]],
#
#         [[207],
#          [202],
#          [220],
#          [225]]], dtype=int32)]

# %%
a
# Out:
# array([[[ 36,  52, 229],
#         [187, 149,  45],
#         [ 34, 212, 134],
#         [193, 209,  36]],
#
#        [[181,  50, 122],
#         [ 95, 192, 186],
#         [ 39,   1,  40],
#         [160,   0,  95]],
#
#        [[  3,  58, 205],
#         [217,  59,  70],
#         [ 88,  56,  50],
#         [ 83, 120,  92]],
#
#        [[152, 167, 207],
#         [ 78,   4, 202],
#         [151, 229, 220],
#         [ 81, 170, 225]]], dtype=int32)

# %%
arr_3_part = np.split(a,3, axis = 2)

# %%
plt.imshow(a)
