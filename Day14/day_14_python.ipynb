# %%
# Seaborn Complete
import seaborn as sns
print('Done')
# Out:
# Done

# %%
# Advance Charts Create
# Matplotlib:- Help(Function: Seaborn)
# Plotly: Python Dashboard(): Dash Module

# Seborn: Doc: https://seaborn.pydata.org/

# %%
# Seaborn All Datasets
print(sns.get_dataset_names())
print(len(sns.get_dataset_names()))
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']
# 22

# %%
# Internet Required
df_titanic = sns.load_dataset('titanic')
df_titanic.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 542         0       3  female  11.0      4      2  31.275        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 542  child       False  NaN  Southampton    no  False

# %%
# sns.countplot
# sns.barplot
# sns.boxplot
# sns.scatterplot
# sns.catplot
# sns.pairplot
# sns.heatmap
# sns.regplot
# sns.lmplot
# sns.lineplot
# sns.kdeplot
# sns.violinplot

# %%
import matplotlib.pyplot as plt
sns.countplot(data = df_titanic, x = 'sex', hue = 'alive',palette= sns.color_palette('magma',2))  # hue: further divide: based on categorical(object)
plt.title('Titanic survival Analysis Bases on gender!')
plt.show()

# %%
df_titanic_sampl
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked  class  who  \
# 313         0       3  male  28.0      0      0  7.8958        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 313        True  NaN  Southampton    no   True

# %%
#barlot
sns.barplot(data = df_titanic, x = 'class', y = 'fare',hue='alive',estimator='mean')
plt.show()

# %%
# sns.barplot

sns.barplot(data = df_titanic, x= 'class', y = 'fare',hue = 'alive',estimator='mean',errorbar=('ci',0),palette=sns.color_palette(('rainbow'),2))# min, max, sum
plt.grid(color='r',alpha=0.1)
plt.show()
# Confidence Interval(CI): 95%

# %%
#sns.boxplot:to detect outliers and to check data distribution
#to detect outliers:
# Range: Min to max(19 - 22): 35, 28, 45(Outliers: fliers)
# # Q2: Quantile : 50%
# # Q1: 25%
# # Q3: 75%

# # IQR = Q3 - Q1
# UW(Upper cap) = Q3 + 1.5*IQR
# LW(Lower cap) = Q1 - 1.5* IQR

# %%
# sns.boxplot

sns.boxplot(data = df_titanic, x='class', y ='fare',hue='sex', orient='h')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
# sns.boxplot

sns.boxplot(data = df_titanic, y='class', x ='fare',hue='sex', orient='h')
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
# sns.violin plot

plt.figure(figsize = (10,5))
sns.violinplot(data = df_titanic, x='class', y   = 'fare' , hue = 'sex',orient = 'v')
plt.show()

# %%
df_pen = sns.load_dataset('penguins')
df_pen.sample()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 217  Chinstrap  Dream            49.6           18.2              193.0
#
#      body_mass_g   sex
# 217       3775.0  Male

# %%
sns.violinplot(data = df_pen, x = 'species', y = 'body_mass_g' , hue = 'sex')
plt.show()

# %%
#scatterplot

# %%
# sns.scatterplot
# numerical vs Numerical Analysis
#used to do correlationb/w two numerical values

# %%
sns.scatterplot(data = df_pen , x= 'bill_length_mm', y = 'bill_depth_mm', hue = 'species')
plt.show()

# %%
sns.regplot(data = df_pen , x= 'bill_length_mm', y = 'bill_depth_mm')
plt.show()

# %%
df_tips = sns.load_dataset('tips')
df_tips.sample()
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 157        25.0  3.75  Female     No  Sun  Dinner     4

# %%
# cat plot

sns.catplot(data = df_tips, x= 'total_bill', y = 'tips',kind='violin',hue='sex',row='smoker',col='day')#kind:strip,
plt.show()

# %%
sns.lmplot(data = df_tips, x= 'total_bill', y = 'tip')
plt.show()
sns.relplot(data = df_tips, x= 'total_bill', y = 'tip',kind = 'scatter')

# %%
sns.lmplot(data = df_tips, x= 'total_bill', y = 'tip',row = 'smoker', col='day',hue='sex')
plt.show()

# %%
sns.relplot(data = df_tips, x= 'total_bill', y = 'tip',kind = 'scatter', hue = 'sex', row = 'smoker', col='day')
plt.show()

# %%
# line plot

df_flight = sns.load_dataset('flights')
df_flight.sample()
# Out:
#     year month  passengers
# 41  1952   Jun         218

# %%
df_flight.head(10)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136
# 9  1949   Oct         119

# %%
sns.lineplot(data = df_flight, x= 'year', y = 'passengers',hue='month',linestyle=':')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
# sns.pairplot(num vsnum)

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# sns.pairplot( num vs num)

df_iris = sns.load_dataset('iris')
df_iris.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 11            4.8          3.4           1.6          0.2      setosa
# 147           6.5          3.0           5.2          2.0   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 15            5.7          4.4           1.5          0.4      setosa
# 73            6.1          2.8           4.7          1.2  versicolor

# %%
df_iris.iloc[:,:-1].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# # >0: +ve : + ve Corr
# =0: No corr
# <0: -ve: - ve Corr

# %%
sns.pairplot(data=df_iris)

# %%
sns.pairplot(data=df_iris,hue='species')

# %%
sns.pairplot(data=df_iris,hue='species',corner=True)

# %%
# sns.kdeplot : Kernel density estimation

sns.kdeplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue = 'species')
sns.scatterplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue = 'species')
plt.show()

# %%
# sns.kdeplot : Kernel density estimation

sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width', hue = 'species',) # kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
plt.show()

# %%
# sns.kdeplot : Kernel density estimation

sns.jointplot(data = df_iris, x = 'sepal_length', y = 'sepal_width',kind = 'reg') # kind : { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }
plt.show()

# %%
pip install cowsay
# Out:
# Collecting cowsayNote: you may need to restart the kernel to use updated packages.
#
#   Downloading cowsay-6.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading cowsay-6.1-py3-none-any.whl (25 kB)
# Installing collected packages: cowsay
# Successfully installed cowsay-6.1

# %%
import cowsay
cowsay.cow('dhruv')
# Out:
#   _____
# | dhruv |
#   =====
#      \
#       \
#         ^__^
#         (oo)\_______
#         (__)\       )\/\
#             ||----w |
#             ||     ||

# %%
import IPython
IPython.display.YouTubeVideo('zlNQ7q0SSRw&ab_channel=RajShamani',allow_autoplay=True)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/zlNQ7q0SSRw&ab_channel=RajShamani?autoplay=1"
#             frameborder="0"
#             allowfullscreen
#             allow="autoplay"
#         ></iframe>
